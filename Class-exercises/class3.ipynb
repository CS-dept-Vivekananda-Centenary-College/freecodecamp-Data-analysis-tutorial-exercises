# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
# %matplotlib inline

# %%
df = pd.read_csv('./data/class3/IPL IMB381IPL2013.csv')

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.describe()
# Out:
#            Sl.NO.         AGE        T-RUNS      T-WKTS    ODI-RUNS-S  \
# count  130.000000  130.000000    130.000000  130.000000    130.000000
# mean    65.500000    2.092308   2166.715385   66.530769   2508.738462
# std     37.671829    0.576627   3305.646757  142.676855   3582.205625
# min      1.000000    1.000000      0.000000    0.000000      0.000000
# 25%     33.250000    2.000000     25.500000    0.000000     73.250000
# 50%     65.500000    2.000000    542.500000    7.000000    835.000000
# 75%     97.750000    2.000000   3002.250000   47.500000   3523.500000
# max    130.000000    3.000000  15470.000000  800.000000  18426.000000
#
#          ODI-SR-B    ODI-WKTS   ODI-SR-BL  CAPTAINCY EXP       RUNS-S  ...  \
# count  130.000000  130.000000  130.000000     130.000000   130.000000  ...
# mean    71.164385   76.076923   34.033846       0.315385   514.246154  ...
# std     25.898440  111.205070   26.751749       0.466466   615.226335  ...
# ...

# %%
sn.barplot(x='AGE', y='SOLD PRICE', data=df)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='SOLD PRICE'>

# %%
sn.barplot(x='COUNTRY', y='SOLD PRICE', data=df)
# Out:
# <AxesSubplot:xlabel='COUNTRY', ylabel='SOLD PRICE'>

# %%
sn.barplot(x='PLAYING ROLE', y='SOLD PRICE', data=df)
# Out:
# <AxesSubplot:xlabel='PLAYING ROLE', ylabel='SOLD PRICE'>

# %%
sn.barplot(x='AGE', y='SOLD PRICE', hue='PLAYING ROLE', data=df)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='SOLD PRICE'>

# %%
plt.hist(df['SOLD PRICE'])
# Out:
# (array([27., 32., 21., 20., 14.,  7.,  0.,  1.,  4.,  4.]),
#  array([  20000.,  198000.,  376000.,  554000.,  732000.,  910000.,
#         1088000., 1266000., 1444000., 1622000., 1800000.]),
#  <BarContainer object of 10 artists>)

# %%
df.hist('SOLD PRICE')
# Out:
# array([[<AxesSubplot:title={'center':'SOLD PRICE'}>]], dtype=object)

# %%
sn.histplot(df['SOLD PRICE'])
# Out:
# <AxesSubplot:xlabel='SOLD PRICE', ylabel='Count'>

# %%
sn.distplot(df['SOLD PRICE'])
# Out:
# C:\Users\Soumya\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SOLD PRICE', ylabel='Density'>

# %%
sn.distplot(df['AGE'])
# Out:
# C:\Users\Soumya\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AGE', ylabel='Density'>

# %%
sn.boxplot(df['SOLD PRICE'])
# Out:
# C:\Users\Soumya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SOLD PRICE'>

# %%
df[df['SOLD PRICE']>1350000.0][['PLAYER NAME', 'AGE', 'PLAYING ROLE', 'SOLD PRICE']]
# Out:
#        PLAYER NAME  AGE PLAYING ROLE  SOLD PRICE
# 15       Dhoni, MS    2    W. Keeper     1500000
# 23     Flintoff, A    2   Allrounder     1550000
# 50        Kohli, V    1      Batsman     1800000
# 83   Pietersen, KP    2      Batsman     1550000
# 93       Sehwag, V    2      Batsman     1800000
# 111  Tendulkar, SR    3      Batsman     1800000
# 113     Tiwary, SS    1      Batsman     1600000
# 127   Yuvraj Singh    2      Batsman     1800000

# %%
df[(df['AGE']==2) & (df['SOLD PRICE']>1350000.0)][['PLAYER NAME', 'AGE', 'PLAYING ROLE', 'SOLD PRICE']]
# Out:
#        PLAYER NAME  AGE PLAYING ROLE  SOLD PRICE
# 15       Dhoni, MS    2    W. Keeper     1500000
# 23     Flintoff, A    2   Allrounder     1550000
# 83   Pietersen, KP    2      Batsman     1550000
# 93       Sehwag, V    2      Batsman     1800000
# 127   Yuvraj Singh    2      Batsman     1800000

# %%
sn.boxplot(x='PLAYING ROLE', y='SOLD PRICE', data=df)
# Out:
# <AxesSubplot:xlabel='PLAYING ROLE', ylabel='SOLD PRICE'>

# %%
sn.boxplot(x='TEAM', y='SOLD PRICE', data=df)
# Out:
# <AxesSubplot:xlabel='TEAM', ylabel='SOLD PRICE'>

# %%
sn.boxplot(x='COUNTRY', y='SOLD PRICE', data=df)
# Out:
# <AxesSubplot:xlabel='COUNTRY', ylabel='SOLD PRICE'>

# %%
batsman_df = df[df['PLAYING ROLE'] == 'Batsman']
batsman_df.head()
# Out:
#     Sl.NO.     PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 4        5    Badrinath, S    2     IND   CSK      Batsman      63       0
# 5        6      Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 11      12  Chanderpaul, S    3      WI   RCB      Batsman    9918       9
# 14      15       Dhawan, S    2     IND   MI+      Batsman       0       0
# 18      19      Dravid, RS    3     IND  RCB+      Batsman   13288       1
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 4           79     45.93  ...  120.71      28       0     0     0.0  0.00
# 5          172     72.26  ...   95.45       0       0     0     0.0  0.00
# 11        8778     70.74  ...   80.64       0       0     0     0.0  0.00
# 14          69     56.09  ...  122.32      36      66     4    16.5  8.25
# 18       10889     71.24  ...  116.88      23       0     0     0.0  0.00
#
#     SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
sn.scatterplot(x='SIXERS', y='SOLD PRICE', data=batsman_df)
# Out:
# <AxesSubplot:xlabel='SIXERS', ylabel='SOLD PRICE'>

# %%
sn.regplot(x='SIXERS', y='SOLD PRICE', data=batsman_df)
# Out:
# <AxesSubplot:xlabel='SIXERS', ylabel='SOLD PRICE'>

# %%
sn.pairplot(df[['SR-B', 'AVE', 'SIXERS', 'SOLD PRICE']], size=5)
# Out:
# C:\Users\Soumya\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df[['SR-B', 'AVE', 'SIXERS', 'SOLD PRICE']].corr()
# Out:
#                 SR-B       AVE    SIXERS  SOLD PRICE
# SR-B        1.000000  0.583579  0.425394    0.184278
# AVE         0.583579  1.000000  0.705365    0.396519
# SIXERS      0.425394  0.705365  1.000000    0.450609
# SOLD PRICE  0.184278  0.396519  0.450609    1.000000

# %%
sn.heatmap(df[['SR-B', 'AVE', 'SIXERS', 'SOLD PRICE']].corr(), annot=True)
# Out:
# <AxesSubplot:>
